-- %% [markdown]
-- # [EtlNetflix]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [EtlNetflix]    Script Date: 8/12/2022 10:51:34 AM ******/
CREATE DATABASE [EtlNetflix]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'EtlNetflix', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.TREINAMENTOALURA\MSSQL\DATA\EtlNetflix.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'EtlNetflix_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.TREINAMENTOALURA\MSSQL\DATA\EtlNetflix_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [EtlNetflix] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [EtlNetflix].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [EtlNetflix] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [EtlNetflix] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [EtlNetflix] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [EtlNetflix] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [EtlNetflix] SET ARITHABORT OFF 
GO
ALTER DATABASE [EtlNetflix] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [EtlNetflix] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [EtlNetflix] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [EtlNetflix] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [EtlNetflix] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [EtlNetflix] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [EtlNetflix] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [EtlNetflix] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [EtlNetflix] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [EtlNetflix] SET  DISABLE_BROKER 
GO
ALTER DATABASE [EtlNetflix] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [EtlNetflix] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [EtlNetflix] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [EtlNetflix] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [EtlNetflix] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [EtlNetflix] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [EtlNetflix] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [EtlNetflix] SET RECOVERY FULL 
GO
ALTER DATABASE [EtlNetflix] SET  MULTI_USER 
GO
ALTER DATABASE [EtlNetflix] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [EtlNetflix] SET DB_CHAINING OFF 
GO
ALTER DATABASE [EtlNetflix] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [EtlNetflix] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [EtlNetflix] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [EtlNetflix] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'EtlNetflix', N'ON'
GO
ALTER DATABASE [EtlNetflix] SET QUERY_STORE = OFF
GO

-- %%
ALTER DATABASE [EtlNetflix] SET  READ_WRITE 
GO
